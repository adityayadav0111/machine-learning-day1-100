# %% [markdown]
# - sharmaji ka beta
# ## Effect of oulier on ML algo
# - Linear Regression
# - Logistic
# - Adaboost
# - Deep Learning
# - weight based algos

# %% [markdown]
# ## How to treat Outliers?
# - Trimming (remove)
# - Capping
# - treating as missing values
# - Discretization
# -

# %%
from PIL import Image
import IPython.display
img = Image.open(r"C:\Users\Admin\Documents\Jupyter Notebook\Machine Learning (CampusX)\Outlier.jpeg")
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x576>

# %% [markdown]
# ## How to Detect outlier?
# - Normal Distribution
# - IQR  for left skew or right skew data
# - for other distrbution

# %%
img = Image.open(r"C:\Users\Admin\Documents\Jupyter Notebook\Machine Learning (CampusX)\WhatsApp Image 2024-11-03 at 15.35.30.jpeg")
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x576>

# %%
img = Image.open(r"C:\Users\Admin\Documents\Jupyter Notebook\Machine Learning (CampusX)\WhatsApp Image 2024-11-03 at 15.41.31.jpeg")
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1600x720>

# %%
img = Image.open(r"C:\Users\Admin\Documents\Jupyter Notebook\Machine Learning (CampusX)\WhatsApp Image 2024-11-03 at 15.41.32.jpeg")
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x576>

# %% [markdown]
# ## Techniques
# - Zscore treatment
# - Iqr based filtering
# - Percentile
# - Winzorization
