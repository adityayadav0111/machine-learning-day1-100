# %% [markdown]
# link: https://www.youtube.com/watch?v=4HyTlbHUKSw

# %% [markdown]
# ## Uni means Single and Variate means Variable

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Types of Data
# 1. Numerical
#    - Height, weight,price
# 3. Catgorical
#    - nationality, gender

# %%
df = pd.read_csv(r'C:\Users\Admin\Documents\Jupyter Notebook\Machine Learning (CampusX)\Dataset\train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Flow
# - Have a look on entire columns present in a data
# - see the relationshp/effect on output column
# - just think of single column

# %% [markdown]
# ## If data is Categorical Data

# %% [markdown]
# ## a. Countplot

# %%
# sns.countplot(x='Survived',data=df)
# df['Survived'].value_counts()
sns.countplot(x='Pclass',data=df,hue='Survived')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %% [markdown]
# ## Piechart

# %%
df['Pclass'].value_counts().plot(kind='pie',autopct='%1.3f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # 2. Numerical

# %% [markdown]
# # a. Histogram

# %%
plt.hist(df['Age'])   ## to find Distribution of data
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # b. Distplot   --skewness in data

# %%
sns.distplot(df['Age'])  ##Explained
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6864\1886487148.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])  ##Explained
# <Axes: xlabel='Age', ylabel='Density'>

# %%
df['Age'].skew()   ## 0 - perfectly skewed, + positively skewed to the right side and - means negatively skewwed to left side
# Out:
# 0.38910778230082704

# %% [markdown]
# # c. Boxplot

# %% [markdown]
# - 5 no summary
# - to identify outlier

# %%
sns.boxplot(df['Fare'])
# Out:
# <Axes: ylabel='Fare'>
