# %% [markdown]
# ## What is mixed data?
# - numerical + categorical
# - example B5
# - Funda we need to split this two columns one will store category and other will numerical
# -

# %%
from PIL import Image
import IPython.display
import pandas as pd
import numpy as np

img = Image.open(r'C:\Users\Admin\Documents\Jupyter Notebook\Machine Learning (CampusX)\MixedData.jpeg')
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1600x720>

# %%
df = pd.read_csv(r"C:\Users\Admin\Documents\Jupyter Notebook\Machine Learning (CampusX)\Dataset\titanic.csv")
df.head()
# Out:
#   Cabin            Ticket number  Survived
# 0   NaN         A/5 21171      5         0
# 1   C85          PC 17599      3         1
# 2   NaN  STON/O2. 3101282      6         1
# 3  C123            113803      3         1
# 4   NaN            373450      A         0

# %%
df.shape
# Out:
# (891, 4)

# %% [markdown]
# ## Note:
# 1.

# %%
df['number'].unique()
# Out:
# array(['5', '3', '6', 'A', '2', '1', '4'], dtype=object)

# %%
fig = df['number'].value_counts().plot.bar()
fig.set_title("passenger travelling with")
# Out:
# Text(0.5, 1.0, 'passenger travelling with')

# %% [markdown]
# ## data - 1. 5 , 2- A, 3 - 5

# %%
## Extracting numerical part
df['number_numerical'] = pd.to_numeric(df['number'],errors='coerce',downcast='integer')

# %%
df['number_categorical'] = np.where(df['number_numerical'].isnull(),df['number'],np.nan)

# %%
df
# Out:
#     Cabin            Ticket number  Survived  number_numerical  \
# 0     NaN         A/5 21171      5         0               5.0
# 1     C85          PC 17599      3         1               3.0
# 2     NaN  STON/O2. 3101282      6         1               6.0
# 3    C123            113803      3         1               3.0
# 4     NaN            373450      A         0               NaN
# ..    ...               ...    ...       ...               ...
# 886   NaN            211536      3         0               3.0
# 887   B42            112053      3         1               3.0
# 888   NaN        W./C. 6607      1         0               1.0
# 889  C148            111369      2         1               2.0
# 890   NaN            370376      3         0               3.0
#
#     number_categorical
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                    A
# ..                 ...
# 886                NaN
# ...

# %%
## Filling values in number column
df['number_numerical'] = df['number_numerical'].fillna(df['number_numerical'].mean())

# %%
df.head()
# Out:
#   Cabin            Ticket number  Survived  number_numerical  \
# 0   NaN         A/5 21171      5         0          5.000000
# 1   C85          PC 17599      3         1          3.000000
# 2   NaN  STON/O2. 3101282      6         1          6.000000
# 3  C123            113803      3         1          3.000000
# 4   NaN            373450      A         0          3.506649
#
#   number_categorical
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                  A

# %%
## since there are only one value 
df['number_categorical'] =df['number_categorical'].fillna(df['number_categorical'].mode())

# %%
df['number_categorical'].unique()
# Out:
# array(['A', nan], dtype=object)

# %%
df['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df['Ticket'].unique()
# Out:
# array(['A/5 21171', 'PC 17599', 'STON/O2. 3101282', '113803', '373450',
#        '330877', '17463', '349909', '347742', '237736', 'PP 9549',
#        '113783', 'A/5. 2151', '347082', '350406', '248706', '382652',
#        '244373', '345763', '2649', '239865', '248698', '330923', '113788',
#        '347077', '2631', '19950', '330959', '349216', 'PC 17601',
#        'PC 17569', '335677', 'C.A. 24579', 'PC 17604', '113789', '2677',
#        'A./5. 2152', '345764', '2651', '7546', '11668', '349253',
#        'SC/Paris 2123', '330958', 'S.C./A.4. 23567', '370371', '14311',
#        '2662', '349237', '3101295', 'A/4. 39886', 'PC 17572', '2926',
#        '113509', '19947', 'C.A. 31026', '2697', 'C.A. 34651', 'CA 2144',
#        '2669', '113572', '36973', '347088', 'PC 17605', '2661',
#        'C.A. 29395', 'S.P. 3464', '3101281', '315151', 'C.A. 33111',
#        'S.O.C. 14879', '2680', '1601', '348123', '349208', '374746',
# ...

# %%
df['cabin_num'] = df['Cabin'].str.extract('(\d+)') ##captures numerical part
df['cabin_cat'] = df['Cabin'].str[0]  #captures the first letter
df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10952\2778697824.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df['cabin_num'] = df['Cabin'].str.extract('(\d+)') ##captures numerical part
#   Cabin            Ticket number  Survived  number_numerical  \
# 0   NaN         A/5 21171      5         0          5.000000
# 1   C85          PC 17599      3         1          3.000000
# 2   NaN  STON/O2. 3101282      6         1          6.000000
# 3  C123            113803      3         1          3.000000
# 4   NaN            373450      A         0          3.506649
#
#   number_categorical cabin_num cabin_cat
# 0                  A       NaN       NaN
# 1                NaN        85         C
# 2                NaN       NaN       NaN
# 3                NaN       123         C
# 4                  A       NaN       NaN

# %%
## Ticket
df['Ticket'].unique()
# Out:
# array(['A/5 21171', 'PC 17599', 'STON/O2. 3101282', '113803', '373450',
#        '330877', '17463', '349909', '347742', '237736', 'PP 9549',
#        '113783', 'A/5. 2151', '347082', '350406', '248706', '382652',
#        '244373', '345763', '2649', '239865', '248698', '330923', '113788',
#        '347077', '2631', '19950', '330959', '349216', 'PC 17601',
#        'PC 17569', '335677', 'C.A. 24579', 'PC 17604', '113789', '2677',
#        'A./5. 2152', '345764', '2651', '7546', '11668', '349253',
#        'SC/Paris 2123', '330958', 'S.C./A.4. 23567', '370371', '14311',
#        '2662', '349237', '3101295', 'A/4. 39886', 'PC 17572', '2926',
#        '113509', '19947', 'C.A. 31026', '2697', 'C.A. 34651', 'CA 2144',
#        '2669', '113572', '36973', '347088', 'PC 17605', '2661',
#        'C.A. 29395', 'S.P. 3464', '3101281', '315151', 'C.A. 33111',
#        'S.O.C. 14879', '2680', '1601', '348123', '349208', '374746',
# ...

# %%
## Extract the last bit of ticket as number

df['ticket_num'] = df['Ticket'].apply(lambda s:s.split()[-1])
df['ticket_num'] = pd.to_numeric(df['ticket_num'],errors='coerce',downcast='integer')

## extracting first part as category
df['ticket_cat'] = df['Ticket'].apply(lambda s:s.split()[0])
df['ticket_cat'] = np.where(df['ticket_cat'].str.isdigit(),np.nan,df['ticket_cat'])

df.head(20)
# Out:
#    Cabin            Ticket number  Survived  number_numerical  \
# 0    NaN         A/5 21171      5         0          5.000000
# 1    C85          PC 17599      3         1          3.000000
# 2    NaN  STON/O2. 3101282      6         1          6.000000
# 3   C123            113803      3         1          3.000000
# 4    NaN            373450      A         0          3.506649
# 5    NaN            330877      2         0          2.000000
# 6    E46             17463      2         0          2.000000
# 7    NaN            349909      5         0          5.000000
# 8    NaN            347742      1         1          1.000000
# 9    NaN            237736      A         1          3.506649
# 10    G6           PP 9549      1         1          1.000000
# 11  C103            113783      1         1          1.000000
# 12   NaN         A/5. 2151      3         0          3.000000
# 13   NaN            347082      3         0          3.000000
# ...
