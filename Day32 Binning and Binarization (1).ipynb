# %% [markdown]
# from sklearn.preprocessing import KBinsDiscretizer
# - params = bins, strategy,(uniform,quantile and kmeans) ,encoding(ordinal,ohe))

# %% [markdown]
# ## Encoding Numerical Features

# %% [markdown]
# - Why??
# 1. Suppose we have vastly sparse data like 24-10000-10000000 in that case it is important that data can be properly binned

# %% [markdown]
# ## Types:
# 1. Discretization i.e Binning
# - Descretization is the process of transforming continous varaiables into discrete varaiables by creating a sett of continous intervals that span the range of the varaiables'value. Descretization is also called binning,where is bin aletrnative name for interval (simple mein bole toh histogram)
# - Use??   -1. to handle outlier   2.to improve teh value spread  3. no change in spread of data
# - ## Types
#   1. Unsupervised:
#      - Equal Width (Uniform Binning)
#      - Equal Frequency(quantile)
#      - Kmeans Binning
#   2. Supervised (later)
#      - Decision Tree Binning
#   3. Custom Binning
# 3. Binarization

# %% [markdown]
# ## 1. Equal Width (Uniform Binning)

# %%
from PIL import Image
from IPython.display import display

# Replace 'your_image.jpg' with the path to your image file
img = Image.open(r'C:\Users\Admin\Documents\Jupyter Notebook\Machine Learning (CampusX)\WhatsApp Image 2024-10-29 at 14.20.35.jpeg')
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x576>

# %% [markdown]
# # 2 Equal Frequency / Quantile Binning

# %% [markdown]
# - Outlier
# - Value Spread --- uniform karta hai
# - instead of ranges it uses quantile

# %%
img = Image.open(r"C:\Users\Admin\Documents\Jupyter Notebook\Machine Learning (CampusX)\WhatsApp Image 2024-10-29 at 14.33.06.jpeg")
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x576>

# %% [markdown]
# ## 3. K-means Binning
# - forms clusters
# - interval ko centroid bolte hai yaha
