# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %%
X,y = make_classification(n_features=5,n_redundant=0, n_informative=5,n_clusters_per_class=1)

# %%
df = pd.DataFrame(X,columns=['col1','col2','col3','col4','col5'])
df['target'] =y
df.head()
# Out:
#        col1      col2      col3      col4      col5  target
# 0 -1.126935 -0.636280 -1.089368  0.534141  1.768064       1
# 1 -1.308170 -2.095310  0.723714 -1.790831 -1.169721       0
# 2 -2.010315 -1.644033 -1.236466 -0.569556 -1.343815       0
# 3 -1.850310  0.137661  0.456016 -2.369360 -1.153587       0
# 4 -0.473467  0.590051 -2.077727  1.305969  1.147410       1

# %%
bag = BaggingClassifier(max_features=2)  ## splitting is based on 0 and 1st column
bag.fit(df.iloc[:,:5],df.iloc[:,-1])
# Out:
# BaggingClassifier(max_features=2)

# %%
plt.figure(figsize=(12,12))
plot_tree(bag.estimators_[0])
plt.show()

# %%
bag.estimators_
# Out:
# [DecisionTreeClassifier(random_state=1887672749),
#  DecisionTreeClassifier(random_state=218657645),
#  DecisionTreeClassifier(random_state=1198621376),
#  DecisionTreeClassifier(random_state=1263148279),
#  DecisionTreeClassifier(random_state=1973453677),
#  DecisionTreeClassifier(random_state=2134241865),
#  DecisionTreeClassifier(random_state=575344692),
#  DecisionTreeClassifier(random_state=267726041),
#  DecisionTreeClassifier(random_state=1441277993),
#  DecisionTreeClassifier(random_state=650397065)]

# %%
rf = RandomForestClassifier(max_features=2) ## splitting is based on most of the column at each node level

# %%
rf.fit(df.iloc[:,:5],df.iloc[:,-1])
# Out:
# RandomForestClassifier(max_features=2)

# %%
plt.figure(figsize=(12,12))
plot_tree(rf.estimators_[4])
plt.show()
